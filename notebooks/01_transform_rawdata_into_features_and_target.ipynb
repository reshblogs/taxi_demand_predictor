# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
from src.data import *
from src.visual import *

# %%
# Download raw data

download_files_raw(2022)
# Out:
# Downloaded files :  ['rides_2022-01.parquet', 'rides_2022-02.parquet', 'rides_2022-03.parquet', 'rides_2022-04.parquet', 'rides_2022-05.parquet', 'rides_2022-06.parquet', 'rides_2022-07.parquet', 'rides_2022-08.parquet', 'rides_2022-09.parquet', 'rides_2022-10.parquet', 'rides_2022-11.parquet', 'rides_2022-12.parquet']

# %%
# Validate the raw data

validate_data_files()
# Out:
#                  pickup_time  pickup_location
# 0        2022-01-01 00:35:40              142
# 1        2022-01-01 00:33:43              236
# 2        2022-01-01 00:53:21              166
# 3        2022-01-01 00:25:21              114
# 4        2022-01-01 00:36:48               68
# ...                      ...              ...
# 33002506 2022-10-31 23:56:35              137
# 33002507 2022-10-31 23:22:00              142
# 33002508 2022-10-31 23:25:00              186
# 33002509 2022-10-31 23:32:54              264
# 33002510 2022-10-31 23:21:34              166
#
# [33002511 rows x 2 columns]

# %%
# Transform the validated data into Time Series data

transform_to_timeseries()
# Out:
#                 pickup_time  pickup_location  count_pickup_loc
# 0       2022-01-01 00:00:00               61                 1
# 1       2022-01-01 00:00:00               97                 1
# 2       2022-01-01 00:00:00               10                 1
# 3       2022-01-01 00:00:00               74                 9
# 4       2022-01-01 00:00:00              140                38
# ...                     ...              ...               ...
# 1911547 2022-10-31 23:00:00              256                 0
# 1911548 2022-10-31 23:00:00              257                 0
# 1911549 2022-10-31 23:00:00              258                 0
# 1911550 2022-10-31 23:00:00              259                 0
# 1911551 2022-10-31 23:00:00              260                 0
#
# [1911552 rows x 3 columns]

# %%
# Transform Time Series data into Training Data (Features, Target)

window_size = 672 #1 month i.e., 28 days => 28*24 hours = 672
step_size = 24

features,target = transform_timeseriesdata_into_features_target(window_size,step_size)
print("Features : ",features.shape,"\Target : ",target.shape)
display(features)
display(target)
# Out:
# Features :  (72312, 674) \Target :  (72312, 1)
#        rides_previous_672_hours  rides_previous_671_hours  \
# 0                             1                         1
# 1                             0                         4
# 2                             0                         0
# 3                             0                         0
# 4                             0                         0
# ...                         ...                       ...
# 72307                         3                         4
# 72308                         9                         4
# 72309                         7                         6
# 72310                         6                         5
# 72311                         8                         1
#
#        rides_previous_670_hours  rides_previous_669_hours  \
# 0                             0                         2
# 1                             1                         2
# ...

# %%
# Visualize a sample of training data

fig = plot_training_sample(features,target,1000) #Row = 1000
fig.show()
# Out:
# <div>                            <div id="a74bcf86-5506-4c81-b7cf-20c8ef7ea166" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a74bcf86-5506-4c81-b7cf-20c8ef7ea166")) {                    Plotly.newPlot(                        "a74bcf86-5506-4c81-b7cf-20c8ef7ea166",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2022-06-22T00:00:00","2022-06-22T01:00:00","2022-06-22T02:00:00","2022-06-22T03:00:00","2022-06-22T04:00:00","2022-06-22T05:00:00","2022-06-22T06:00:00","2022-06-22T07:00:00","2022-06-22T08:00:00","2022-06-22T09:00:00","2022-
# ...
